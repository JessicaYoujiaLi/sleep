# %% [markdown]
# <a href="https://colab.research.google.com/github/GergelyTuri/sleep/blob/master/notebooks/Cosine_dist_calc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prototype notebook to calculate cosine distance for a dataset
#
# * 3/10/2024

# %%
# !git clone https://github.com/GergelyTuri/sleep.git

# %%
# %cd sleep
# !pip install .

# %%
# %cd sleep
# !git pull
# Out:
# [Errno 2] No such file or directory: 'sleep'
# /content/sleep
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), 610 bytes | 610.00 KiB/s, done.
# From https://github.com/GergelyTuri/sleep
#    8155535..62f9d6d  master     -> origin/master
# Updating 8155535..62f9d6d
# Fast-forward
#  src/google_drive.py | 19 ++++++++++++++++++-
#  1 file changed, 18 insertions(+), 1 deletion(-)

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from os.path import join
from sleep.src import google_drive

# %%
useful_data = google_drive.useful_datasets()
useful_data
# Out:
#          mouseID     day                            sessionID  cellType  \
# 0   5HT2afl05b_1  7_7_SD        TSeries-07072021-0833_GC1-001        GC
# 1   5HT2afl05b_1  7_7_SD        TSeries-07072021-0833_GC2-003        GC
# 2   5HT2afl05b_1  7_7_SD        TSeries-07072021-0833_MC1-002        MC
# 3   5HT2afl05b_1  7_7_SD        TSeries-07072021-0833_MC2-004        MC
# 4   5HT2afl05b_2  7_6_SD         TSeries-07062021-0844_GC-001        GC
# 5   5HT2afl05b_2  7_6_SD         TSeries-07062021-0844_MC-002        MC
# 6   5HT2afl05b_2  7_6_SD        TSeries-07062021-0844_MC2-004        MC
# 7       126031_5   11_23           TSeries-11232022-GC-MC-002        GC
# 8      sert52b_1  4_3_SD   TSeries-04032023-1323_SD_sess1-001        GC
# 9      sert52b_5  4_3_SD            TSeries-04032023-1323-001        GC
# 10     sert54a_5     4_4      TSeries-04042023-1023_sess1-001        GC
# 11      140503_2    1_16   TSeries-01162024-0853_dendrite-001  dendrite
# ...

# %%
exp_path = google_drive.return_exp_path('5HT2afl05b_1', '7_7_SD', 'TSeries-07072021-0833_GC1-001')
exp_path
# Out:
# '/gdrive/Shareddrives/Turi_lab/Data/Sleep/2p/Analysis/data/5HT2afl05b_1/7_7_SD/TSeries-07072021-0833_GC1-001'
